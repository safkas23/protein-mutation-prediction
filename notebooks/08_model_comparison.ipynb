# %%
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,r2_score
import pandas as pd

# %%
models={
"Ridge":Ridge(),

"RandomForest":
RandomForestRegressor(),

"GradientBoosting":
GradientBoostingRegressor()
}

# %%
rows=[]

for name,m in models.items():
    for feature,Xtr,Xte in [
    ("Physicochemical",
     X_train_phys,
     X_test_phys),

    ("ESM",
     X_train_esm,
     X_test_esm),

    ("Hybrid",
     X_train_hybrid,
     X_test_hybrid)
    ]:

        m.fit(Xtr,y_train_esm)
        preds=m.predict(Xte)
        rows.append({

        "Model":name,
        "Features":feature,

        "MAE":mean_absolute_error(
        y_test_esm,
        preds
        ),

        "R2":r2_score(
        y_test_esm,
        preds
        )
        })

# %%
pd.DataFrame(rows).to_csv(
"../results/model_family_comparison.csv",
index=False
)
