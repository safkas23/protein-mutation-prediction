# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, r2_score

vectorizer = CountVectorizer(
    analyzer="char",
    ngram_range=(1,2),
    max_features=5000
)

X_train_vec = vectorizer.fit_transform(X_train_text)
X_test_vec = vectorizer.transform(X_test_text)

models = {
    "Ridge": Ridge(),
    "Random Forest": RandomForestRegressor(n_estimators=20, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42)
}

results = []

for name, model in models.items():
    model.fit(X_train_vec, y_train)
    preds = model.predict(X_test_vec)

    results.append({
        "Model": name,
        "MAE": mean_absolute_error(y_test, preds),
        "R2": r2_score(y_test, preds)
    })

results_df = pd.DataFrame(results)
print(results_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4902/240784930.py in <cell line: 0>()
#      10 )
#      11
# ---> 12 X_train_vec = vectorizer.fit_transform(X_train_text)
#      13 X_test_vec = vectorizer.transform(X_test_text)
#      14
#
# NameError: name 'X_train_text' is not defined
